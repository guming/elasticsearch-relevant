# %% [markdown]
# # Setup Code (Listings 3 & 4) 5.2.1

# %%
import requests
import json
import os
from elasticsearch import Elasticsearch
from elasticsearch.helpers import streaming_bulk

client = Elasticsearch("http://localhost:9200")

# Some utilities for flattening the explain into something a bit more
# readable. Pass Explain JSON, get something readable (ironically this is what Solr's default output is :-p)
def flatten(l):
    [item for sublist in l for item in sublist]

def simplerExplain(explainJson, depth=0):
    result = " " * (depth * 2) + "%s, %s\n" % (explainJson['value'], explainJson['description'])
    #print json.dumps(explainJson, indent=True)
    if 'details' in explainJson:
        for detail in explainJson['details']:
            result += simplerExplain(detail, depth=depth+1)
    return result


# To speed up the pace of development, we really need to focus more heavily on the analysis and query
# settings of the search engine, rather than fidly bits of the http interface.
#
# To that end, we're going to collapse some of the code you were introduced to in chapter 3 into more general functions,
# so we can reuse them. Largely, this is the exact same code you saw in chapter 3 some more generality.

## Analyze
## The analyze function is a helper for accessing the _analyze endpoint like we did in chapter 3. Recall,
## given a field or analyzer, passing some text to _analyze will return the token stream that results from
## that analyzer. This token stream, if you recall, shows us exactly how the search engine translate text
## into individual tokens to be consumed by the underlying data structures. When we debug analysis, we see
## matches we need to expect.
def analyze(text, field=None, analyzer=None):
#     whatToAnalyze = ''
#     if field is not None:
#         whatToAnalyze = "field=%s" % field
#     elif analyzer is not None:
#         whatToAnalyze = "analyzer=%s" % analyzer
#     resp = requests.get("http://localhost:9200/tmdb/_analyze?%s&format=yaml" % whatToAnalyze, 
#                         data=text)
    f = {
      "field": field,
      "text": text,
        "analyzer":analyzer

    }
    resp = client.indices.analyze(index="tmdb",body=f)
    print json.dumps(resp, indent=2)
    
## Search
## Next we need to wrap up our execution of query DSL queries. The function 'search' will execute the passed query DSL
## query and display the results. 
## If a scoring explain is associated with the results, then it also gets displayed,
## We'll also be sure to dump the query DSL
def search(query, verbose=False):
    resp = client.search(index="tmdb", body=query)
    searchHits = resp['hits']
    print "Num\tRelevance Score\t\tMovie Title"
    for idx, hit in enumerate(searchHits['hits']):
            castNames = []            
            castCharacters = []                        
            directorNames = []
            for cast in hit['_source']['cast']:
                castNames.append(cast['name'])
                castCharacters.append(cast['character'])
            for director in hit['_source']['directors']:
                directorNames.append(director['name'])
            print "%s\t%s\t\t%s" % (idx + 1, hit['_score'], hit['_source']['title'])
            if verbose:
                mid = hit['_id']
                print "%s" % hit['_source']['title']
                print "%s" % hit['_source']['tagline']        
                print "%s" % hit['_source']['overview']        
                print "%s" % hit['_id']
                print "DIRS %s" % directorNames
                print "CAST %s" % castNames
                print "CHAR %s" % castCharacters
                if '_explanation' in hit:
                    print "%s" % simplerExplain(hit['_explanation'])
                    print "*************************************"
    
    if verbose:
        resp = client.indices.validate_query(index="tmdb",doc_type="_doc",body=query,rewrite=True)
        print "*************************************"
        print json.dumps(resp, indent=2)

## Reindex
## Reindex takes analyzer and field mappings, recreates the index, and then reindexes
## TMDB movies using the _bulk index API. There are other ways for modifying the configuration
## of the index besides dropping and restarting, however for convenience and because our data
## isn't truly that large, we'll just delete and start from scratch when we need to.
def reindex(analysisSettings, mappingSettings=None, movieDict={}):
    # Destroy any existing index (equiv to SQL "drop table")
    result = client.indices.delete(index='tmdb', ignore=[400, 404])
    print "Delete TMDB Index <%s>" % result
    
    # Create the index with explicit settings
    # We need to explicitely set number of shards to 1 to eliminate the impact of 
    # distributed IDF on our small collection
    # See also "Relavance is Broken!"
    # http://www.elastic.co/guide/en/elasticsearch/guide/current/relevance-is-broken.html
    settings = {
        "settings": {
            "number_of_shards": 1,
            "index": {
                "analysis" : analysisSettings,
            }
        }
    }
    if mappingSettings:
        settings['mappings'] = mappingSettings
    resp = client.indices.create(index="tmdb",body=settings)
    print "Create TMDB Index <%s>" % resp

    # Bulk index title & overview to the movie endpoint
    print "Indexing %i movies" % len(movieDict.keys())
    bulkMovies = ""
    print "creating..."
    for id, movie in movieDict.iteritems(): 
        result = client.create(index='tmdb', doc_type='_doc', id=movie["id"], body=json.dumps(movie))

    print "indexing..."
## Extract
## major difference between our use of TMDB here and in chapter 3: pulling more data. Not only do we access the 
## movie endpoint, we also extract the credits -- pulling in the cast (actors and such) and extracting the director.
def extract(movieIds=[], numMovies=10000):
    if len(movieIds) == 0:
        try:
            f = open('tmdb.json')
            if f:
                return json.loads(f.read());
        except IOError:
            pass       
    return movieDict

# %% [markdown]
# # 5.2.2 -- Listing 4, Index to ES, Search

# %%
movieDict = extract()

analysis = {
    "analyzer" : {
      "default" : {
        "type" : "english"
        }
      }
   }

# reindex(analysisSettings=analysis, movieDict=movieDict)

usersSearch = 'basketball with cartoon aliens'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.1', 'overview'],
         }
    },
    'size': 5,
    'explain': True
}
search(query)
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.1', 'overview'],
         }
    }
}
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	12.882349		Space Jam
# 2	7.5384703		Grown Ups
# 3	7.4996777		Speed Racer
# 4	7.244087		Semi-Pro
# 5	7.1626425		The Flintstones
# ===============
# Num	Relevance Score		Movie Title
# 1	12.882349		Space Jam
# Space Jam
# Get ready to jam.
# Michael Jordan agrees to help the Looney Tunes play a basketball game against alien slavers to determine their freedom.
# 2300
# DIRS [u'Joe Pytka']
# CAST [u'Michael Jordan', u'Wayne Knight', u'Billy West', u'Dee Bradley Baker', u'Theresa Randle', u'Danny DeVito', u'Brandon Hammond', u'Larry Bird', u'Bill Murray', u'Charles Barkley', u'Patrick Ewing', u'Tyrone Bogues', u'Larry Johnson', u'Shawn Bradley', u'Ahmad Rashad', u'Del Harris', u'Vlade Divac', u'Cedric Ceballos', u'Jim Rome', u'Paul Westphal', u'Danny Ainge', u'Alonzo Mourning', u'A.C. Green', u'Charles Oakley', u'Derek Harper', u'Jeff Malone', u'Anthony Miller', u'Sharone Wright']
# CHAR [u'Himself', u'Stan Podolak', u'Bugs Bunny/Elmer Fudd (voice)', u'Daffy Duck/Tazmanian Devil/Bull (voice)', u'Juanita Jordan', u'Mr. Swackhammer (voice)', u'Michael Jordan (at 10)', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself', u'Himself']
# 2	7.5384703		Grown Ups
# Grown Ups
# Boys will be boys. . . some longer than others.
# After their high school basketball coach passes away, five good friends and former teammates reunite for a Fourth of July holiday weekend.
# 38365
# DIRS [u'Dennis Dugan']
# CAST [u'Adam Sandler', u'Salma Hayek', u'Maria Bello', u'Steve Buscemi', u'Maya Rudolph', u'Kevin James', u'Rob Schneider', u'Chris Rock', u'Jamie Chung', u'David Spade', u'Ebony Jo-Ann', u'Di Quon', u'Colin Quinn', u'Tim Meadows', u'Madison Riley', u'Dan Patrick']
# CHAR [u'Lenny Feder', u'Roxanne Chase-Feder', u'Sally Lamonsoff', u'Wiley', u'Deanne McKenzie', u'Eric Lamonsoff', u'Rob Hilliard', u'Kurt McKenzie', u'Amber Hilliard', u'Marcus Higgins', u'Mama Ronzoni', u'Rita', u'Dickie Bailey', u'Malcolm', u'Jasmine Hilliard', u'Norby The Ride Guy']
# 3	7.4996777		Speed Racer
# Speed Racer
# Go!
# Speed racer is the tale of a young and brilliant racing driver. When corruption in the racing leagues costs his brother his life, he must team up with the police and the mysterious Racer X to bring and end to the corruption and criminal activities. Inspired by the cartoon series.
# 7459
# DIRS [u'Lana Wachowski', u'Andy Wachowski']
# CAST [u'Emile Hirsch', u'Christina Ricci', u'Matthew Fox', u'Susan Sarandon', u'Scott Porter', u'John Goodman', u'Hiroyuki Sanada', u'Art LaFleur', u'Richard Roundtree', u'Togo Igawa', u'Nan Yu', u'Cosma Shiva Hagen', u'Roger Allam', u'Nayo Wallace', u'Rain', u'Moritz Bleibtreu', u'Benno F\xfcrmann', u'Ralph Herforth']
# CHAR [u'Speed Racer', u'Trixie', u'Racer X', u'Mom Racer', u'Rex Racer', u'Pops Racer', u'Mr. Musha', u'Fuji Announcer', u'Ben Burns', u'Mr. Togokahn', u'Horuko Togokahn', u'Gennie', u'Royalton', u'Minx', u'Taejo Togokahn', u'Grey Ghost', u'Inspektor Detektor', u'Cannonball Taylor']
# 4	7.244087		Semi-Pro
# Semi-Pro
# Putting the funk into the dunk.
# Jackie Moon is the owner, promoter, coach, and star player of the Flint Michigan Tropics of the American Basketball Association (ABA). In 1976 before the ABA collapses, the National Basketball Association (NBA) plans to merge with the best teams of the ABA at the end of the season. Only the top four teams will make the move and the worst teams will fold. The Tropics are the worst team in the league and if they want to make it to the NBA, Jackie Moon must rally his team and start winning. The only problem is the fact that Jackie Moon is not really the coach and star basketball player he thinks he is. To keep his team from oblivion and leave his mark in the city, Jackie Moon must inspire his team to win fourth place in the playoffs.
# 13260
# DIRS [u'Kent Alterman']
# CAST [u'Will Ferrell', u'Maura Tierney', u'Woody Harrelson', u'David Koechner', u'Will Arnett', u'Andr\xe9 Benjamin', u'Andy Richter', u'Rob Corddry', u'Tim Meadows', u'Jackie Earle Haley', u'Matt Walsh', u'Kristen Wiig', u'Andrew Daly', u'DeRay Davis']
# CHAR [u'Jackie Moon', u'Lynn', u'Monix', u'Commissioner', u'Lou Redwood', u'Clarence', u'Bobby Dee', u'Kyle', u'Cornelius', u'Dukes', u'Father Pat', u'', u'Dick Pepperfield', u'Bee Bee Ellis']
# 5	7.1626425		The Flintstones
# The Flintstones
# Yabba-Dabba-Doo!
# Modern Stone Age family the Flintstones hit the big screen in this live-action version of the classic cartoon. Fred helps Barney adopt a child. Barney sees an opportunity to repay him when Slate Mining tests its employees to find a new executive. But no good deed goes unpunished.
# 888
# DIRS [u'William Hanna', u'Joseph Barbera', u'Brian Levant']
# CAST [u'John Goodman', u'Elizabeth Perkins', u'Rick Moranis', u"Rosie O'Donnell", u'Kyle MacLachlan', u'Halle Berry', u'Elizabeth Taylor', u'Dann Florek', u'Richard Moll', u'Irwin Keyes', u'Jonathan Winters', u'Harvey Korman', u'Corey Burton', u'Roger L. Jackson', u'Jean Vander Pyl']
# CHAR [u'Fred Flintstone', u'Wilma Flintstone', u'Barney Rubble', u'Betty Rubble', u'Cliff Vandercave', u'Rosetta Stone', u'Pearl Slaghoople', u'Mr. Slate', u'Hoagie', u'Joe Rockhead', u'Gobo The Grizzled Man', u"Ali / Dicabird / Blossom's Adopted Doll Son Ali", u'Triple X / Green Goose', u'Bobo', u'Tanya Slag']
# 6	6.943389		Coach Carter
# Coach Carter
# It begins on the street. It ends here.
# Based on a true story, in which Richmond High School head basketball coach Ken Carter made headlines in 1999 for benching his undefeated team due to poor academic results.
# 7214
# DIRS [u'Thomas Carter']
# CAST [u'Samuel L. Jackson', u'Rob Brown', u"Robert Ri'chard", u'Rick Gonzalez', u'Channing Tatum', u'Texas Battle', u'Lacey Beeman', u'Octavia Spencer']
# CHAR [u'Ken Carter', u'Kenyon Stone', u'Damien Carter', u'Timo Cruz', u'Jason Lyle', u'Maddux', u'Susan', u'Mrs. Battle']
# 7	6.7653713		White Men Can't Jump
# White Men Can't Jump
# It ain't easy being this good.
# Billy Hoyle (Woody Harrelson) and Sidney Deane (Wesley Snipes) are an unlikely pair of basketball hustlers. They team up to con their way across the courts of Los Angeles, playing a game that's fast dangerous - and funny.
# 10158
# DIRS [u'Ron Shelton']
# CAST [u'Wesley Snipes', u'Woody Harrelson', u'Rosie Perez', u'Tyra Ferrell']
# CHAR [u'Sidney Deane', u'Billy Hoyle', u'Gloria Clement', u'Rhonda Deane']
# 8	5.845222		Meet Dave
# Meet Dave
# There's a Whole Other World Going on Inside of Him.
# A crew of miniature aliens operate a spaceship that has a human form. While trying to save their planet, the aliens encounter a new problem, as their ship becomes smitten with an Earth woman.
# 11260
# DIRS [u'Brian Robbins']
# CAST [u'Eddie Murphy', u'Elizabeth Banks', u'Gabrielle Union', u'Scott Caan', u'Ed Helms', u'Kevin Hart', u'Pat Kilbane', u'Judah Friedlander', u'Marc Blucas', u'Jim Turner', u'Austyn Myers', u'Mario Loya', u"Mike O'Malley", u'Allisyn Ashley Arm']
# CHAR [u'Dave Ming Chang / Kapit\xe4n', u'Gina Morrison', u'Nr.3- Kulturoffizierin', u'Dooley', u'Nr.2- Stellvertreter des Kapit\xe4ns', u'Nr. 17', u'Nr.4- Sicherheitsoffizier', u'Ingenieur', u'Mark', u'Doktor', u'Josh Morrison', u'Old Navy Customer', u'Knox', u'Nerdy Girl']
# 9	5.800564		Aliens vs Predator: Requiem
# Aliens vs Predator: Requiem
# The Last Place On Earth We Want To Be Is In The Middle
# A sequel to 2004's Alien vs. Predator, the iconic creatures from two of the scariest film franchises in movie history wage their most brutal battle ever - in our own backyard. The small town of Gunnison, Colorado becomes a war zone between two of the deadliest extra-terrestrial life forms - the Alien and the Predator. When a Predator scout ship crash-lands in the hills outside the town, Alien Facehuggers and a hybrid Alien/Predator are released and begin to terrorize the town.
# 440
# DIRS [u'Colin Strause', u'Greg Strause']
# CAST [u'Steven Pasquale', u'Reiko Aylesworth', u'John Ortiz', u'Ariel Gade', u'Sam Trammell', u'Kristen Hager', u'Robert Joy', u'David Paetkau', u'Tom Woodruff Jr.', u'Ian Whyte', u'Chelah Horsdal', u'Meshach Peters', u'Matt Ward', u'Gina Holden', u'Kurt Max Runte', u'Liam James', u'Ty Olsson', u'Chris William Martin', u'Rekha Sharma', u'Catherine Lough Haggquist']
# CHAR [u'Dallas Howard', u"Kelly O'Brien", u'Sheriff Eddie Morales', u"Molly O'Brien", u'Tim', u'Jesse', u'Col. Stevens', u'Dale', u'Alien', u'Predator', u'Darcy', u'Curtis', u'Mark', u'Carrie', u'Buddy', u'Sam', u'Nathan', u'Deputy Ray', u'Nurse Helen', u'Tina']
# 10	5.440302		Bedazzled
# Bedazzled
# Meet the Devil. She's giving Elliott seven wishes. But not a chance in Hell.
# Elliot Richardson, suicidal techno geek, is given seven wishes to turn his life around when he meets up with a very seductive Satan. The catch: his soul. Some of his wishes include a 7 foot basketball star, a rock star, and a hamburger. But, as could be expected, the Devil must put her own little twist on each his fantasies.
# 1636
# DIRS [u'Harold Ramis']
# CAST [u'Elizabeth Hurley', u'Brendan Fraser', u"Frances O'Connor", u'Orlando Jones', u'Paul Adelstein', u'Toby Huss', u'Gabriel Casseus', u'Miriam Shor', u'Brian Doyle-Murray', u'Jeff Doucette', u'Aaron Lustig']
# CHAR [u'The Devil', u'Elliot', u'Alison', u'Daniel/Dan/Danny, Esteban, Beach Jock, Lamar Garrett, Dr. Ngegitigegitibaba', u'Bob/Roberto/Beach Jock', u'Jerry/Alejandro/Beach Jock/Jerry Turner', u'Angel', u'Carol/Penthouse Hostess', u'Priest', u'Desk Sergeant', u'Synedyne Supervisor']
# *************************************
# {
#   "valid": true,
#   "explanations": [
#     {
#       "index": "tmdb",
#       "explanation": "((overview:basketbal overview:cartoon overview:alien) | (title:basketbal title:cartoon title:alien)^0.1)",
#       "valid": true
#     }
#   ],
#   "_shards": {
#     "successful": 1,
#     "failed": 0,
#     "total": 1
#   }
# }

# %% [markdown]
# # 5.2.4 -- Listing 5 Inspecting Nested Star Trek Docs

# %%
spaceJamId = 2300
httpResp = requests.get("http://localhost:9200/tmdb/_doc/%s" % spaceJamId)
spaceJamDoc = json.loads(httpResp.text)
print json.dumps(spaceJamDoc['_source'], indent=True)
# Out:
# {
#  "poster_path": "/9T9ucCk6wO0crRBUIkBJMRAVcKp.jpg",
#  "production_countries": [
#   {
#    "iso_3166_1": "US",
#    "name": "United States of America"
#   }
#  ],
#  "revenue": 230000000,
#  "overview": "Michael Jordan agrees to help the Looney Tunes play a basketball game against alien slavers to determine their freedom.",
#  "video": false,
#  "id": 2300,
#  "genres": [
#   {
#    "id": 16,
#    "name": "Animation"
#   },
#   {
#    "id": 35,
#    "name": "Comedy"
#   },
#   {
#    "id": 18,
#    "name": "Drama"
#   },
#   {
#    "id": 14,
#    "name": "Fantasy"
#   },
#   {
#    "id": 10751,
#    "name": "Family"
#   }
#  ],
#  "title": "Space Jam",
#  "tagline": "Get ready to jam.",
#  "vote_count": 275,
#  "homepage": "",
#  "belongs_to_collection": null,
#  "original_language": "en",
#  "status": "Released",
#  "spoken_languages": [
#   {
#    "iso_639_1": "cs",
#    "name": "\u010cesk\u00fd"
#   },
#   {
#    "iso_639_1": "fr",
#    "name": "Fran\u00e7ais"
#   },
#   {
#    "iso_639_1": "pl",
#    "name": "Polski"
#   },
#   {
#    "iso_639_1": "en",
#    "name": "English"
#   }
#  ],
#  "imdb_id": "tt0117705",
#  "adult": false,
#  "backdrop_path": "/kBTdPNTAzagAY6UiwY957KCDGuu.jpg",
#  "production_companies": [
#   {
#    "name": "Warner Bros. Animation",
#    "id": 2785
#   },
#   {
#    "name": "Warner Bros. Entertainment",
#    "id": 17
#   }
#  ],
#  "release_date": "1996-11-15",
#  "popularity": 0.778260445788321,
#  "original_title": "Space Jam",
#  "budget": 80000000,
#  "cast": [
#   {
#    "name": "Michael Jordan",
#    "character": "Himself",
#    "id": 23678,
#    "credit_id": "52fe434bc3a36847f80496c9",
#    "cast_id": 2,
#    "profile_path": "/7y16frD57Ztzk2mY4JeI2pQQhan.jpg",
#    "order": 0
#   },
#   {
#    "name": "Wayne Knight",
#    "character": "Stan Podolak",
#    "id": 4201,
#    "credit_id": "52fe434bc3a36847f80496cd",
#    "cast_id": 3,
#    "profile_path": "/oW9aeZwkz1S1IMjQGtd9mnvlEax.jpg",
#    "order": 1
#   },
#   {
#    "name": "Billy West",
#    "character": "Bugs Bunny/Elmer Fudd (voice)",
#    "id": 23679,
#    "credit_id": "52fe434bc3a36847f80496d1",
#    "cast_id": 4,
#    "profile_path": "/9V9fsfmWjHEDbS8tB5EOdHkyMFg.jpg",
#    "order": 2
#   },
#   {
#    "name": "Dee Bradley Baker",
#    "character": "Daffy Duck/Tazmanian Devil/Bull (voice)",
#    "id": 23680,
#    "credit_id": "52fe434bc3a36847f80496d5",
#    "cast_id": 5,
#    "profile_path": "/zFXwtsdvUCeNkzCzYpYZdAmTkJY.jpg",
#    "order": 3
#   },
#   {
#    "name": "Theresa Randle",
#    "character": "Juanita Jordan",
#    "id": 4604,
#    "credit_id": "52fe434bc3a36847f80496d9",
#    "cast_id": 6,
#    "profile_path": "/18LVR034VKDGOFqDw1EA1VZQVoe.jpg",
#    "order": 4
#   },
#   {
#    "name": "Danny DeVito",
#    "character": "Mr. Swackhammer (voice)",
#    "id": 518,
#    "credit_id": "52fe434bc3a36847f80496dd",
#    "cast_id": 7,
#    "profile_path": "/zKuyzmKzPLG7RJo7lbbHjx6CCZc.jpg",
#    "order": 5
#   },
#   {
#    "name": "Brandon Hammond",
#    "character": "Michael Jordan (at 10)",
#    "id": 23681,
#    "credit_id": "52fe434bc3a36847f80496e1",
#    "cast_id": 8,
#    "profile_path": "/ooljlVi5IYf2w4Px3jqc8OQdjjS.jpg",
#    "order": 6
#   },
#   {
#    "name": "Larry Bird",
#    "character": "Himself",
#    "id": 23682,
#    "credit_id": "52fe434bc3a36847f80496e5",
#    "cast_id": 9,
#    "profile_path": "/1KRnQVsXS8mz4tHHWD1yPAQBXq2.jpg",
#    "order": 7
#   },
#   {
#    "name": "Bill Murray",
#    "character": "Himself",
#    "id": 1532,
#    "credit_id": "52fe434bc3a36847f80496e9",
#    "cast_id": 12,
#    "profile_path": "/eb58HuFIrxS0zUmbmW4d8YXTbje.jpg",
#    "order": 8
#   },
#   {
#    "name": "Charles Barkley",
#    "character": "Himself",
#    "id": 1211812,
#    "credit_id": "5361746b0e0a2649bf0004e6",
#    "cast_id": 37,
#    "profile_path": "/mqHWhTtrja9vI8kfI6z7tCq5gB1.jpg",
#    "order": 9
#   },
#   {
#    "name": "Patrick Ewing",
#    "character": "Himself",
#    "id": 1231141,
#    "credit_id": "53614c6cc3a368397e0001d2",
#    "cast_id": 19,
#    "profile_path": "/aaXM8PuixEHNTLmvBQJLH8vV1SV.jpg",
#    "order": 11
#   },
#   {
#    "name": "Tyrone Bogues",
#    "character": "Himself",
#    "id": 1232432,
#    "credit_id": "53614e44c3a36839650001b4",
#    "cast_id": 20,
#    "profile_path": null,
#    "order": 12
#   },
#   {
#    "name": "Larry Johnson",
#    "character": "Himself",
#    "id": 1225517,
#    "credit_id": "53614eb1c3a36839650001bc",
#    "cast_id": 21,
#    "profile_path": "/gbfwZWitnSrcQwkAughr5Ji4iT5.jpg",
#    "order": 13
#   },
#   {
#    "name": "Shawn Bradley",
#    "character": "Himself",
#    "id": 1234833,
#    "credit_id": "5361565a0e0a2649b800027a",
#    "cast_id": 22,
#    "profile_path": null,
#    "order": 14
#   },
#   {
#    "name": "Ahmad Rashad",
#    "character": "Himself",
#    "id": 1197748,
#    "credit_id": "5361566c0e0a2649a6000277",
#    "cast_id": 23,
#    "profile_path": null,
#    "order": 15
#   },
#   {
#    "name": "Del Harris",
#    "character": "Himself",
#    "id": 1251369,
#    "credit_id": "536156930e0a2649b800027f",
#    "cast_id": 24,
#    "profile_path": null,
#    "order": 16
#   },
#   {
#    "name": "Vlade Divac",
#    "character": "Himself",
#    "id": 193304,
#    "credit_id": "536156a50e0a2649a90002a3",
#    "cast_id": 25,
#    "profile_path": "/ivflYHUbWXKyDe5B9su5HSidMA9.jpg",
#    "order": 17
#   },
#   {
#    "name": "Cedric Ceballos",
#    "character": "Himself",
#    "id": 1230823,
#    "credit_id": "536156d20e0a2649b8000282",
#    "cast_id": 26,
#    "profile_path": null,
#    "order": 18
#   },
#   {
#    "name": "Jim Rome",
#    "character": "Himself",
#    "id": 1215304,
#    "credit_id": "536156e10e0a2649ad000272",
#    "cast_id": 27,
#    "profile_path": null,
#    "order": 19
#   },
#   {
#    "name": "Paul Westphal",
#    "character": "Himself",
#    "id": 1315402,
#    "credit_id": "536156ee0e0a2649b8000285",
#    "cast_id": 28,
#    "profile_path": null,
#    "order": 20
#   },
#   {
#    "name": "Danny Ainge",
#    "character": "Himself",
#    "id": 1315446,
#    "credit_id": "536156fe0e0a2649ad000275",
#    "cast_id": 29,
#    "profile_path": null,
#    "order": 21
#   },
#   {
#    "name": "Alonzo Mourning",
#    "character": "Himself",
#    "id": 180625,
#    "credit_id": "5361571f0e0a2649b8000287",
#    "cast_id": 30,
#    "profile_path": "/ukR2lS5Z8avrJnN3Kua1ks3Habf.jpg",
#    "order": 22
#   },
#   {
#    "name": "A.C. Green",
#    "character": "Himself",
#    "id": 1315447,
#    "credit_id": "5361572a0e0a2649bf000295",
#    "cast_id": 31,
#    "profile_path": null,
#    "order": 23
#   },
#   {
#    "name": "Charles Oakley",
#    "character": "Himself",
#    "id": 1315403,
#    "credit_id": "536157540e0a2649bf00029b",
#    "cast_id": 32,
#    "profile_path": "/l35FQsV529lOhDFvMGk8aJ82AV9.jpg",
#    "order": 24
#   },
#   {
#    "name": "Derek Harper",
#    "character": "Himself",
#    "id": 1315448,
#    "credit_id": "536157680e0a2649a90002b5",
#    "cast_id": 33,
#    "profile_path": null,
#    "order": 25
#   },
#   {
#    "name": "Jeff Malone",
#    "character": "Himself",
#    "id": 1315449,
#    "credit_id": "536157780e0a2649a6000287",
#    "cast_id": 34,
#    "profile_path": null,
#    "order": 26
#   },
#   {
#    "name": "Anthony Miller",
#    "character": "Himself",
#    "id": 1315450,
#    "credit_id": "536157ba0e0a2649bb0002d3",
#    "cast_id": 35,
#    "profile_path": null,
#    "order": 27
#   },
#   {
#    "name": "Sharone Wright",
#    "character": "Himself",
#    "id": 1315451,
#    "credit_id": "536157cb0e0a2649bf0002a7",
#    "cast_id": 36,
#    "profile_path": null,
#    "order": 28
#   }
#  ],
#  "directors": [
#   {
#    "name": "Joe Pytka",
#    "department": "Directing",
#    "job": "Director",
#    "credit_id": "52fe434bc3a36847f80496c5",
#    "profile_path": "/c46Ah1KxlfC4W8mHVrGDsJ7dMPJ.jpg",
#    "id": 23677
#   }
#  ],
#  "vote_average": 6.3,
#  "runtime": 88
# }

# %% [markdown]
# # 5.3.1, Listing 6 Star Trek Query Using Query from Ch 3

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name', 'directors.name'],      
            'type': 'best_fields'
         }
    },
    'size': 50,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	7.1845765		Hannah Montana: The Movie
# 2	7.1596975		Vertigo
# 3	6.9732013		Star Trek: Insurrection
# 4	6.9093037		One Flew Over the Cuckoo's Nest
# 5	6.906671		Legion
# 6	6.906671		Halo 4: Forward Unto Dawn
# 7	6.906671		Priest
# 8	6.906671		Dark Skies
# 9	6.71099		Star Trek: First Contact
# 10	6.5468693		Gnomeo & Juliet
# 11	6.5468693		Excalibur
# 12	6.465148		X-Men: Days of Future Past
# 13	6.3152065		Panic Room
# 14	6.2415876		Conspiracy Theory
# 15	6.228061		The Bounty Hunter
# 16	6.0993795		Star Trek: Nemesis
# 17	6.0993795		Star Trek: Generations
# 18	6.0993795		Robin Hood: Men in Tights
# 19	6.030678		The Wolverine
# 20	6.009052		Drive Angry
# 21	6.009052		Feast
# 22	6.009052		District 13: Ultimatum
# 23	6.009052		The Expendables 3
# 24	6.009052		Underworld: Rise of the Lycans
# 25	6.009052		My Bloody Valentine
# 26	5.833557		X-Men
# 27	5.7091494		Dune
# 28	5.6086707		Ted
# 29	5.589937		Save the Last Dance
# 30	5.589937		TMNT
# 31	5.475602		X2: X-Men United
# 32	5.475602		The Prince of Egypt
# 33	5.443809		The SpongeBob SquarePants Movie
# 34	5.443809		10 Things I Hate About You
# 35	5.29683		The Beaver
# 36	5.2604103		A Time to Kill
# 37	5.199648		Zathura: A Space Adventure
# 38	5.1590357		X-Men: The Last Stand
# 39	5.0623937		Sex and the City 2
# 40	5.0623937		Sex and the City
# 41	5.0623937		Doubt
# 42	4.944413		One for the Money
# 43	4.944413		The SpongeBob Movie: Sponge Out of Water
# 44	4.944413		The Kings of Summer
# 45	4.881914		Valhalla Rising
# 46	4.8770733		The Collector
# 47	4.7924466		Guess Who
# 48	4.7710886		The Inbetweeners Movie
# 49	4.720683		The Last Starfighter
# 50	4.6651835		The Twilight Saga: Breaking Dawn - Part 1
# ===============
# Num	Relevance Score		Movie Title
# 1	7.1845765		Hannah Montana: The Movie
# Hannah Montana: The Movie
# She has the best of both worlds...now she has to choose just one.
# When Miley Stewart (aka pop-star Hannah Montana) gets too caught up in the superstar celebrity lifestyle, her dad decides it's time for a total change of scenery. But sweet nibblets! Miley must trade in all the glitz and glamour of Hollywood for some ol' blue jeans on the family farm in Tennessee, and question if she can be both Miley Stewart and Hannah Montana. With a little help from her friends – and awesome guest stars Taylor Swift, Rascal Flatts and Vanessa Williams – will she figure out whether to choose Hannah or Miley?
# 18126
# DIRS [u'Peter Chelsom']
# CAST [u'Miley Cyrus', u'Billy Ray Cyrus', u'Emily Osment', u'Jason Earles', u'Taylor Swift', u'Lucas Till', u'Mitchel Musso', u'Mois\xe9s Arias', u'Vanessa Williams', u'Margo Martindale', u'Melora Hardin', u'Brooke Shields', u'Brandon Cyrus']
# CHAR [u'Miley Stewart/Hannah Montana', u'Billy Ray Stewart', u'Lilly Truscott', u'Jackson Rod Stewart', u'Herself', u'Travis Brody', u'Oliver Oken', u'Rico', u'Vita', u'Ruby', u'Lorelai', u"Miley's Mom", u'Extra']
# 7.1845765, max of:
#   7.1845765, sum of:
#     7.1845765, weight(overview:stewart in 2277) [PerFieldSimilarity], result of:
#       7.1845765, score(freq=2.0), computed as boost * idf * tf from:
#         2.2, boost
#         6.3184767, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           5, n, number of documents containing term
#           3050, N, total number of documents with field
#         0.5168519, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           2.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           64.0, dl, length of field (approximate)
#           36.697704, avgdl, average length of field
#
# *************************************
# 2	7.1596975		Vertigo
# Vertigo
# Alfred Hitchcock engulfs you in a whirlpool of terror and tension!
# A retired San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.
# 426
# DIRS [u'Alfred Hitchcock']
# CAST [u'James Stewart', u'Kim Novak', u'Barbara Bel Geddes', u'Tom Helmore', u'Henry Jones', u'Raymond Bailey', u'Ellen Corby', u'Konstantin Shayne', u'Lee Patrick', u'Bess Flowers']
# CHAR [u"Det. John 'Scottie' Ferguson", u'Madeleine Elster/Judy Barton', u"Marjorie 'Midge' Wood", u'Gavin Elster', u'Coroner', u"Scottie's doctor", u'Manager of McKittrick Hotel', u'Pop Leibel', u'Car owner mistaken for Madeleine', u"Diner at Ernie's"]
# 7.1596975, max of:
#   7.1596975, sum of:
#     2.9440267, weight(cast.name:patrick in 116) [PerFieldSimilarity], result of:
#       2.9440267, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.5532162, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           21.0, dl, length of field
#           37.233192, avgdl, average length of field
#     4.2156706, weight(cast.name:stewart in 116) [PerFieldSimilarity], result of:
#       4.2156706, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.5532162, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           21.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 3	6.9732013		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 6.9732013, max of:
#   6.9732013, sum of:
#     2.8673406, weight(cast.name:patrick in 578) [PerFieldSimilarity], result of:
#       2.8673406, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.53880596, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           23.0, dl, length of field
#           37.233192, avgdl, average length of field
#     4.1058607, weight(cast.name:stewart in 578) [PerFieldSimilarity], result of:
#       4.1058607, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.53880596, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           23.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 4	6.9093037		One Flew Over the Cuckoo's Nest
# One Flew Over the Cuckoo's Nest
# If he's crazy, what does that make you?
# While serving time for insanity at a state mental hospital, implacable rabble-rouser Randle Patrick McMurphy inspires his fellow patients to rebel against the authoritarian rule of head nurse Mildred Ratched.
# 510
# DIRS [u'Milo\u0161 Forman']
# CAST [u'Jack Nicholson', u'Louise Fletcher', u'Danny DeVito', u'William Redfield', u'Scatman Crothers', u'Brad Dourif', u'Christopher Lloyd', u'Will Sampson', u'Dean R. Brooks', u'Michael Berryman', u'Sydney Lassick', u'William Duell', u'Vincent Schiavelli']
# CHAR [u'Randle Patrick McMurphy', u'Nurse Mildred Ratched', u'Martini', u'Harding', u'Orderly Turkle', u'Billy Bibbit', u'Taber', u'Chief Bromden', u'Dr. John Spivey', u'Ellis', u'Charlie Cheswick', u'Jim Sefelt', u'Fredrickson']
# 6.9093037, max of:
#   6.9093037, sum of:
#     6.9093037, weight(overview:patrick in 498) [PerFieldSimilarity], result of:
#       6.9093037, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         6.008322, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           7, n, number of documents containing term
#           3050, N, total number of documents with field
#         0.5227071, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           25.0, dl, length of field
#           36.697704, avgdl, average length of field
#
# *************************************
# 5	6.906671		Legion
# Legion
# When the last angel falls, the fight for mankind begins.
# An out-of-the-way diner becomes the unlikely battleground for the survival of the human race. When God loses faith in humankind, he sends his legion of angels to bring on the Apocalypse. Humanity's only hope lies in a group of strangers trapped in a desert diner with the Archangel Michael.
# 22894
# DIRS [u'Scott Stewart']
# CAST [u'Paul Bettany', u'Dennis Quaid', u'Kevin Durand', u'Kate Walsh', u'Doug Jones', u'Lucas Black', u'Tyrese Gibson', u'Adrianne Palicki', u'Charles S. Dutton', u'Jon Tenney', u'Kate Walsh', u'Jeanette Miller', u'Cameron Harlow', u'Josh Stamberg', u'Yancey Arias', u'Willa Holland']
# CHAR [u'Michael', u'Bob Hanson', u'Gabriel', u'Sandra Anderson', u'Ice Cream Man', u'Jeep Hanson', u'Kyle Williams', u'Charlie', u'Percy Walker', u'Howard Anderson', u'Sandra Anderson', u'Gladys Foster', u'Minivan Boy', u'Burton', u'Estevez', u'Audrey Anderson']
# 6.906671, max of:
#   6.906671, sum of:
#     6.906671, weight(directors.name:stewart in 1377) [PerFieldSimilarity], result of:
#       6.906671, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         6.519475, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           4, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.48154122, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           2.0, dl, length of field
#           2.3176007, avgdl, average length of field
#
# *************************************
# 6	6.906671		Halo 4: Forward Unto Dawn
# Halo 4: Forward Unto Dawn
# The story of Halo 4 begins at dawn.
# Set against the backdrop of a UNSC military academy, a group of highborn cadets are training to be the next generation of soldiers in the UNSC’s ongoing war with insurrectionists in the outer colonial planets. Among these cadets, Thomas Lasky struggles with his doubts about this war, and with the burden of expectations he may not be able to carry. As Lasky comes to terms with his potential as a military leader, the terrifying alien alliance known as the Covenant arrives and turns his world upside down. Inspired by the Master Chief, he must decide what it means to be a hero.
# 119431
# DIRS [u'Stewart Hendler']
# CAST [u'Tom Green', u'Anna Popplewell', u'Iain Belcher', u'Jenna Berman', u'Enisha Brewster', u'Max Carver', u'Ayelet Zurer', u'Masam Holden', u'Mike Dopud', u'Osric Chau']
# CHAR [u'Thomas Lasky', u'Chyler Silva', u'Vickers', u'Kelly-087', u'April Orenski', u'Cadmon Lasky', u'Mehaffey', u'Michael Sullivan', u'General Black', u'Junjie Chen']
# 6.906671, max of:
#   6.906671, sum of:
#     6.906671, weight(directors.name:stewart in 1494) [PerFieldSimilarity], result of:
#       6.906671, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         6.519475, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           4, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.48154122, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           2.0, dl, length of field
#           2.3176007, avgdl, average length of field
#
# *************************************
# 7	6.906671		Priest
# Priest
# Vampire Killer
# In an alternate world, humanity and vampires have warred for centuries. After the last Vampire War, the veteran Warrior Priest lives in obscurity with other humans inside one of the Church's walled cities. When the Priest's niece is kidnapped by vampires, the Priest breaks his vows to hunt them down. He is accompanied by the niece's boyfriend, who is a wasteland sheriff, and a former Warrior Priestess.
# 38321
# DIRS [u'Scott Stewart']
# CAST [u'Paul Bettany', u'Cam Gigandet', u'Karl Urban', u'Lily Collins', u'Maggie Q', u'Stephen Moyer', u'M\xe4dchen Amick', u'Christopher Plummer', u'Brad Dourif', u'Alan Dale']
# CHAR [u'Priest', u'Hicks', u'Black Hat', u'Lucy', u'Priestess', u'Aaron', u'Shannon', u'Monsignor Orelas', u'Salesman', u'Monsignor Chamberlain']
# 6.906671, max of:
#   6.906671, sum of:
#     6.906671, weight(directors.name:stewart in 2101) [PerFieldSimilarity], result of:
#       6.906671, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         6.519475, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           4, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.48154122, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           2.0, dl, length of field
#           2.3176007, avgdl, average length of field
#
# *************************************
# 8	6.906671		Dark Skies
# Dark Skies
# Once you have been chosen. You belong to them.
# From the producers of Paranormal Activity, Insidious, and Sinister comes Dark Skies: a supernatural thriller that follows a young family living in the suburbs. As husband and wife Daniel and Lacey Barret witness an escalating series of disturbing events involving their family, their safe and peaceful home quickly unravels. When it becomes clear that the Barret family is being targeted by an unimaginably terrifying and deadly force, Daniel and Lacey take matters in their own hands to solve the mystery of what is after their family.
# 145135
# DIRS [u'Scott Stewart']
# CAST [u'Keri Russell', u'Josh Hamilton', u'Dakota Goyo', u'J.K. Simmons', u'Trevor St. John', u'Annie Thurman', u'Myndy Crist', u'Ron Ostrow', u'Josh Wingate', u'Kadan Rockett', u'L.J. Benet', u'Rich Hutchman', u'Jake Brennan', u'Tom Costello', u'Marion Kerr', u'Alyvia Alyn Lind', u'Josh Stamberg', u'Tiffany Jeneen', u'Brian Stepanek', u'Judith Moreland', u'Adam Schneider', u'Jessica Borden', u'Kenneth Meseroll', u'Trevor St. John', u'Andy Umberger', u'Michael Patrick McGill', u'Alexandra Anthony', u'Scott Anthony']
# CHAR [u'Lacy Barrett', u'Daniel', u'Jesse', u'Edwin Pollard', u'Alex Holcombe', u'Shelly', u'Karen', u'Richard', u'Gun Salesperson', u'Sam Barrett', u'Kevin Ratner', u'Mike Jessop', u'Bobby Jessop (as Jake Washburn)', u'Young Father', u'Young Mother', u'Young Daughter', u'Police Officer', u'Protection One Operator', u'Security System Technician', u'Janice Rhodes', u'Young Husband', u'Young Wife', u'Pete', u'Alex Holcombe', u'Doctor Jonathan Kooper', u"Ratner's Father", u'Naughty Cheerleader (as Alexandra Fulton)', u'Naughty Teacher']
# 6.906671, max of:
#   6.906671, sum of:
#     6.906671, weight(directors.name:stewart in 2131) [PerFieldSimilarity], result of:
#       6.906671, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         6.519475, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           4, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.48154122, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           2.0, dl, length of field
#           2.3176007, avgdl, average length of field
#   1.9349234, sum of:
#     1.9349234, weight(cast.name:patrick in 2131) [PerFieldSimilarity], result of:
#       1.9349234, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.36359417, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           60.0, dl, length of field (approximate)
#           37.233192, avgdl, average length of field
#
# *************************************
# 9	6.71099		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 6.71099, max of:
#   6.71099, sum of:
#     2.7595205, weight(cast.name:patrick in 1034) [PerFieldSimilarity], result of:
#       2.7595205, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.5185454, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           26.0, dl, length of field
#           37.233192, avgdl, average length of field
#     3.9514692, weight(cast.name:stewart in 1034) [PerFieldSimilarity], result of:
#       3.9514692, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.5185454, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           26.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 10	6.5468693		Gnomeo & Juliet
# Gnomeo & Juliet
# A little adventure goes a lawn way.
# A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?
# 45772
# DIRS [u'Kelly Asbury']
# CAST [u'Jason Statham', u'James McAvoy', u'Michael Caine', u'Maggie Smith', u'Julie Walters', u'Patrick Stewart', u'Jim Cummings', u'Ashley Jensen', u'Dolly Parton', u'Matt Lucas', u'Hulk Hogan', u'Stephen Merchant', u'Ozzy Osbourne', u'Emily Blunt']
# CHAR [u'Tybalt (voice)', u'Gnomeo (voice)', u'Lord Redbrick (voice)', u'Lady Bluebury (voice)', u'Lady Montague (voice)', u'William Shakespeare (voice)', u'Featherstone (voice)', u'Nanette (voice)', u'Dolly Gnome (voice)', u'Benny (voice)', u'Terrafirminator V.O. (voice)', u'Paris (voice)', u'Fawn (voice)', u'Juliet (voice)']
# 6.5468693, max of:
#   6.5468693, sum of:
#     2.6920352, weight(cast.name:patrick in 886) [PerFieldSimilarity], result of:
#       2.6920352, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.50586414, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           28.0, dl, length of field
#           37.233192, avgdl, average length of field
#     3.854834, weight(cast.name:stewart in 886) [PerFieldSimilarity], result of:
#       3.854834, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.50586414, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           28.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 11	6.5468693		Excalibur
# Excalibur
# Forged by a god. Foretold by a wizard. Found by a king.
# The myth of King Arthur brought to the screen. Uthur Pendragon is given the mystical sword Excalibur by Merlyn. At his death Uthur buries the sword into a stone, and the next man that can pull it out will be King of England. Years later Arthur, Uthur's bastard son draws Excalibur and becomes king. Arthur's evil half-sister Morgana sires a son with him, who may prove his downfall.
# 11527
# DIRS [u'John Boorman']
# CAST [u'Nigel Terry', u'Helen Mirren', u'Nicholas Clay', u'Cherie Lunghi', u'Paul Geoffrey', u'Nicol Williamson', u'Robert Addie', u'Gabriel Byrne', u'Keith Buckley', u'Katrine Boorman', u'Liam Neeson', u'Corin Redgrave', u'Patrick Stewart', u"Niall O'Brien"]
# CHAR [u'King Arthur', u'Morgana', u'Lancelot', u'Guenevere', u'Perceval', u'Merlin', u'Mordred', u'Uther Pendragon', u'Uryens', u'Igrayne', u'Gawain', u'Cornwall', u'Leondegrance', u'Kay']
# 6.5468693, max of:
#   6.5468693, sum of:
#     2.6920352, weight(cast.name:patrick in 2106) [PerFieldSimilarity], result of:
#       2.6920352, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.50586414, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           28.0, dl, length of field
#           37.233192, avgdl, average length of field
#     3.854834, weight(cast.name:stewart in 2106) [PerFieldSimilarity], result of:
#       3.854834, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.50586414, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           28.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 12	6.465148		X-Men: Days of Future Past
# X-Men: Days of Future Past
# To save the future, they must alter the past
# The ultimate X-Men ensemble fights a war for the survival of the species across two time periods in X-MEN: DAYS OF FUTURE PAST. The beloved characters from the original “X-Men” film trilogy join forces with their younger selves from “X-Men: First Class,” in an epic battle that must change the past – to save our future.
# 127585
# DIRS [u'Bryan Singer']
# CAST [u'Hugh Jackman', u'James McAvoy', u'Patrick Stewart', u'Michael Fassbender', u'Ian McKellen', u'Jennifer Lawrence', u'Nicholas Hoult', u'Ellen Page', u'Shawn Ashmore', u'Peter Dinklage', u'Halle Berry', u'Booboo Stewart', u'Fan Bingbing', u'Daniel Cudmore', u'Adan Canto', u'Omar Sy', u'Evan Peters', u'Lucas Till', u'Josh Helman', u'Evan Jonigkeit', u'Famke Janssen', u'James Marsden', u'Anna Paquin', u'Mark Camacho', u'Kelsey Grammer']
# CHAR [u'Logan / Wolverine', u'Professor Charles Xavier (Past)', u'Professor Charles Xavier (Future)', u'Erik Lehnsherr / Magneto (Past)', u'Erik Lehnsherr / Magneto (Future)', u'Raven / Mystique', u'Hank McCoy / Beast', u'Kitty Pryde / Shadowcat', u'Iceman', u'Bolivar Trask', u'Ororo Munroe / Storm', u'James Proudstar / Warpath', u'Clarice Ferguson / Blink', u'Piotr Rasputin / Colossus', u'Roberto da Costa / Sunspot', u'Lucas Bishop', u'Pietro Maximoff / Quicksilver', u'Alex Summers / Havok', u'William Stryker', u'Toad', u'Jean Grey', u'Scott Summers / Cyclops', u'Rogue', u'President Richard Nixon', u'Hank McCoy / Beast (Older)']
# 6.465148, max of:
#   6.465148, sum of:
#     2.1213658, weight(cast.name:patrick in 2108) [PerFieldSimilarity], result of:
#       2.1213658, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.39862883, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           50.0, dl, length of field (approximate)
#           37.233192, avgdl, average length of field
#     4.3437824, weight(cast.name:stewart in 2108) [PerFieldSimilarity], result of:
#       4.3437824, score(freq=2.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.57002807, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           2.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           50.0, dl, length of field (approximate)
#           37.233192, avgdl, average length of field
#
# *************************************
# 13	6.3152065		Panic Room
# Panic Room
# It was supposed to be the safest room in the house.
# Trapped in their New York brownstone's panic room, a hidden chamber built as a sanctuary in the event of break-ins, newly divorced Meg Altman (Jodie Foster) and her young daughter Sarah (Kristen Stewart) play a deadly game of cat-and-mouse with three intruders - Burnham (Forest Whitaker), Raoul (Dwight Yoakam) and Junior (Jared Leto) - during a brutal home invasion. But the room itself is the focal point because what the intruders really want is inside it.
# 4547
# DIRS [u'David Fincher']
# CAST [u'Jodie Foster', u'Kristen Stewart', u'Forest Whitaker', u'Dwight Yoakam', u'Jared Leto', u'Patrick Bauchau', u'Ann Magnuson', u'Ian Buchanan', u'Andrew Kevin Walker', u'Paul Schulze', u'Mel Rodriguez', u'Richard Conant', u'Paul Simon', u'Victor Thrash', u'Ken Turner']
# CHAR [u'Meg Altman', u'Sarah Altman', u'Burnham', u'Raoul', u'Junior', u'Stephen Altman', u'Lydia Lynch', u'Evan Kurlander', u'Sleepy Neighbor', u'Officer Keeney', u'Officer Morales', u'SWAT Cop', u'SWAT Cop', u'SWAT Cop', u'SWAT Cop']
# 6.3152065, max of:
#   5.29683, sum of:
#     5.29683, weight(overview:stewart in 1283) [PerFieldSimilarity], result of:
#       5.29683, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         6.3184767, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           5, n, number of documents containing term
#           3050, N, total number of documents with field
#         0.3810491, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           54.0, dl, length of field (approximate)
#           36.697704, avgdl, average length of field
#   6.3152065, sum of:
#     2.596777, weight(cast.name:patrick in 1283) [PerFieldSimilarity], result of:
#       2.596777, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.48796397, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           31.0, dl, length of field
#           37.233192, avgdl, average length of field
#     3.7184298, weight(cast.name:stewart in 1283) [PerFieldSimilarity], result of:
#       3.7184298, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.48796397, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           31.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 14	6.2415876		Conspiracy Theory
# Conspiracy Theory
# What if your most paranoid nightmares had just come true?
# A man obsessed with conspiracy theories becomes a target after one of his theories turns out to be true. Unfortunately, in order to save himself, he has to figure out which theory it is.
# 8834
# DIRS [u'Richard Donner']
# CAST [u'Mel Gibson', u'Julia Roberts', u'Patrick Stewart', u'Cylk Cozart', u'Steve Kahan', u'Terry Alexander', u'Alex McArthur', u'Rod McLachlan', u'Michael Potts', u'Jim Sterling', u'Rich Hebert', u'Brian J. Williams', u'G.A. Aguilar', u'Cece Neber Labao', u'Saxon Trainor']
# CHAR [u'Jerry Fletcher', u'Alice Sutton', u'Dr. Jonas', u'Agent Lowry', u'Mr. Wilson', u'Flip', u'Cynic', u'Justice Guard', u'Justice Guard', u'Justice Guard', u'Public Works Man', u'Clarke', u'Piper', u"Henry Finch's Secretary", u"Alice's Secretary"]
# 6.2415876, max of:
#   6.2415876, sum of:
#     2.5665052, weight(cast.name:patrick in 41) [PerFieldSimilarity], result of:
#       2.5665052, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.4822756, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           32.0, dl, length of field
#           37.233192, avgdl, average length of field
#     3.6750824, weight(cast.name:stewart in 41) [PerFieldSimilarity], result of:
#       3.6750824, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.4822756, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           32.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 15	6.228061		The Bounty Hunter
# The Bounty Hunter
# It's a Job. It Isn't Personal. Well, Maybe a Little...
# Milo Boyd is a bounty hunter whose latest gig is rather satisfying, as he finds out that the bail-skipper he must chase down is his own ex-wife, Nicole -- but she has no intention of getting nabbed without a fight. Complicating matters, Nicole's wannabe-boyfriend, Stewart, joins the chase.
# 27573
# DIRS [u'Andy Tennant']
# CAST [u'Gerard Butler', u'Jennifer Aniston', u'Gio Perez', u'Siobhan Fallon', u'Joel Garland', u'Jason Kolotouros', u'Matt Malloy', u'Jason Sudeikis', u'Adam Rose', u'Christine Baranski', u'Dorian Missick', u'David Costabile', u'Lynda Gravatt', u'Peter Greene', u'Jeff Garlin', u'Charlie Hewson']
# CHAR [u'Milo Boyd', u'Nicole Hurley', u'Uncle Sam', u'Teresa (as Siobhan Fallon Hogan)', u'Dwight (as Joel Marsh Garland)', u'Gelman', u'Gary', u'Stewart', u'Jimmy', u'Kitty Hurley', u'Bobby Jenkins', u'Arthur', u'Judge', u'Earl Mahler', u'Sid', u'Rich Guy']
# 6.228061, max of:
#   6.228061, sum of:
#     6.228061, weight(overview:stewart in 115) [PerFieldSimilarity], result of:
#       6.228061, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         6.3184767, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           5, n, number of documents containing term
#           3050, N, total number of documents with field
#         0.44804102, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           38.0, dl, length of field
#           36.697704, avgdl, average length of field
#
# *************************************
# 16	6.0993795		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS [u'Stuart Baird']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 6.0993795, max of:
#   6.0993795, sum of:
#     2.50803, weight(cast.name:patrick in 577) [PerFieldSimilarity], result of:
#       2.50803, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.47128743, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           34.0, dl, length of field
#           37.233192, avgdl, average length of field
#     3.5913496, weight(cast.name:stewart in 577) [PerFieldSimilarity], result of:
#       3.5913496, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.47128743, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           34.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 17	6.0993795		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS [u'David Carson']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 6.0993795, max of:
#   6.0993795, sum of:
#     2.50803, weight(cast.name:patrick in 1042) [PerFieldSimilarity], result of:
#       2.50803, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.47128743, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           34.0, dl, length of field
#           37.233192, avgdl, average length of field
#     3.5913496, weight(cast.name:stewart in 1042) [PerFieldSimilarity], result of:
#       3.5913496, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.47128743, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           34.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 18	6.0993795		Robin Hood: Men in Tights
# Robin Hood: Men in Tights
# The legend had it coming... Find out where Robin Hood put his Little John, what made Will Scarlet, and what did Friar Tuck into his tights that Maid Marion all of a quiver?
# Robin Hood comes home after fighting in the Crusades to learn that the noble King Richard is in exile and that the despotic King John now rules England, with the help of the Sheriff of Rottingham. Robin Hood assembles a band of fellow patriots to do battle with King John and the Sheriff.
# 8005
# DIRS [u'Mel Brooks']
# CAST [u'Cary Elwes', u'Dom DeLuise', u'Roger Rees', u'Dave Chappelle', u'Eric Allan Kramer', u'Patrick Stewart', u'Megan Cavanagh', u'Richard Lewis', u'Isaac Hayes', u'Amy Yasbeck', u'Mark Blankfield', u'Matthew Porretta', u'Tracey Ullman', u'Dick Van Patten', u'Robert Ridgely', u'Mel Brooks']
# CHAR [u'Robin Hood', u'Don Giovanni', u'Sheriff of Rotingham', u'Ahchoo', u'Little John', u'King Richard', u'Broomhilde', u'Prince John', u'Asneeze', u'Maid Marian', u'Blinkin', u"Will Scarlet O'Hara", u'Latrine', u'The Abbot', u'The Hangman', u'Rabbi Tuckman']
# 6.0993795, max of:
#   6.0993795, sum of:
#     2.50803, weight(cast.name:patrick in 2444) [PerFieldSimilarity], result of:
#       2.50803, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.47128743, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           34.0, dl, length of field
#           37.233192, avgdl, average length of field
#     3.5913496, weight(cast.name:stewart in 2444) [PerFieldSimilarity], result of:
#       3.5913496, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.47128743, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           34.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 19	6.030678		The Wolverine
# The Wolverine
# When he's most vulnerable, he's most dangerous.
# Wolverine faces his ultimate nemesis - and tests of his physical, emotional, and mortal limits - in a life-changing voyage to modern-day Japan.
# 76170
# DIRS [u'James Mangold']
# CAST [u'Hugh Jackman', u'Tao Okamoto', u'Rila Fukushima', u'Hiroyuki Sanada', u'Svetlana Khodchenkova', u'Brian Tee', u'Hal Yamanouchi', u'Will Yun Lee', u'Ken Yamamura', u'Famke Janssen', u'Shinji Ikefuji', u'Qyoko Kudo', u'Conrad Coleby', u'Taris Tyler', u'Sarah Naylor-Liddell', u'Ian McKellen', u'Patrick Stewart']
# CHAR [u'Logan / Wolverine', u'Mariko', u'Yukio', u'Shingen', u'Viper', u'Noburo Mori', u'Yashida', u'Harada', u'Young Yashida', u'Jean Grey', u'Pock-Face', u'Aya', u'Red Beard', u"Bar Man (Red Beard's Friend)", u'Yukon Bar Patron', u'Magneto', u'Professor Xavier']
# 6.030678, max of:
#   6.030678, sum of:
#     2.4797802, weight(cast.name:patrick in 84) [PerFieldSimilarity], result of:
#       2.4797802, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.46597898, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           35.0, dl, length of field
#           37.233192, avgdl, average length of field
#     3.5508976, weight(cast.name:stewart in 84) [PerFieldSimilarity], result of:
#       3.5508976, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.46597898, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           35.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 20	6.009052		Drive Angry
# Drive Angry
# One hell of a ride.
# Milton is a hardened felon who has broken out of Hell, intent on finding the vicious cult who brutally murdered his daughter and kidnapped her baby. He joins forces with Piper, a sexy, tough-as-nails waitress with a 69 Charger, who's also seeking redemption of her own. Caught in a deadly race against time, Milton has three days to avoid capture, avenge his daughter's death, and save her baby before she's mercilessly sacrificed by the cult.
# 47327
# DIRS [u'Patrick Lussier']
# CAST [u'Nicolas Cage', u'Amber Heard', u'William Fichtner', u'Billy Burke', u'David Morse', u'Katy Mixon', u'Charlotte Ross', u'Christa Campbell', u'Todd Farmer', u'Jack McGee', u'Tom Atkins', u'Wanetah Walmsley', u'Edrick Browne', u'Robin McGee', u'Fabian C. Moreno', u'Marc Macaulay', u'Pruitt Taylor Vince', u'Julius Washington', u'Jamie Teer', u'Bryan Massey', u'Timothy Walter', u'Kent Jude Bernard', u'Brent Phillip Henry', u'Gerry May', u'Sherri Talley', u'Arianne Margot', u'Con Schell', u'Nick Gomez', u'Joe Chrest', u'Oakley Lehman', u'Thirl Haston', u'Jake Brake', u'Tim J. Smith', u'Jeffrey J. Dashnaw', u'Tim Trella', u'James Landry H\xe9bert', u'Kenneth Wayne Bradley', u'Kendrick Hudson', u'Michael Papajohn', u'April Littlejohn', u'Henry Kingi', u'Simona Williams', u'Shelby Swatek', u'Joseph Blackstone', u'Dan Forest', u'Elise Fyke', u"Jonathan O'Rear", u'James Paul', u'Alice Searcy', u'Lanie Taylor', u'David Lee Valle']
# ...
# 4.944413, max of:
#   4.944413, sum of:
#     4.944413, weight(overview:patrick in 269) [PerFieldSimilarity], result of:
#       4.944413, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         6.008322, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           7, n, number of documents containing term
#           3050, N, total number of documents with field
#         0.3740579, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           56.0, dl, length of field (approximate)
#           36.697704, avgdl, average length of field
#   1.7342448, sum of:
#     1.7342448, weight(cast.name:stewart in 269) [PerFieldSimilarity], result of:
#       1.7342448, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.22758234, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           128.0, dl, length of field (approximate)
#           37.233192, avgdl, average length of field
#
# *************************************
# 44	4.944413		The Kings of Summer
# The Kings of Summer
# Why live when you can rule.
# Joe Toy, on the verge of adolescence, finds himself increasingly frustrated by his single father, Frank's attempts to manage his life. Declaring his freedom once and for all, he escapes to a clearing in the woods with his best friend, Patrick, and a strange kid named Biaggio. He announces that they are going to build a house there, free from responsibility and parents. Once their makeshift abode is finished, the three young men find themselves masters of their own destiny, alone in the woods.
# 156700
# DIRS [u'Jordan Vogt-Roberts']
# CAST [u'Nick Robinson', u'Gabriel Basso', u'Mois\xe9s Arias', u'Alison Brie', u'Nick Offerman', u'Megan Mullally', u'Mary Lynn Rajskub', u'Angela Trimbur', u'Erin Moriarty', u'Lili Reinhart', u'Marc Evan Jackson', u'Kumail Nanjiani', u'Hannibal Buress', u'Nathan Keyes', u'Austin Abrams', u'Thomas Middleditch']
# CHAR [u'Joe Toy', u'Patrick Keenan', u'Biaggio', u'Heather Toy', u'Frank Toy', u'Mrs. Keenan', u'Captain Davis', u'FacePaint', u'Kelly', u'Vicki', u'Mr. Keenan', u'Delivery Guy', u'Bus Driver', u'Paul', u'Aaron', u'Rookie Cop']
# 4.944413, max of:
#   4.944413, sum of:
#     4.944413, weight(overview:patrick in 2304) [PerFieldSimilarity], result of:
#       4.944413, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         6.008322, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           7, n, number of documents containing term
#           3050, N, total number of documents with field
#         0.3740579, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           56.0, dl, length of field (approximate)
#           36.697704, avgdl, average length of field
#
# *************************************
# 45	4.881914		Valhalla Rising
# Valhalla Rising
#
# 1000 AD, for years, One Eye, a mute warrior of supernatural strength, has been held prisoner by the Norse chieftain Barde. Aided by Are, a boy slave, One Eye slays his captor and together he and Are escape, beginning a journey into the heart of darkness. On their flight, One Eye and Are board a Viking vessel, but the ship is soon engulfed by an endless fog that clears only as the crew sights an unknown land. As the new world reveals its secrets and the Vikings confront their terrible and bloody fate, One Eye discovers his true self.
# 37861
# DIRS [u'Nicolas Winding Refn']
# CAST [u'Mads Mikkelsen', u'Gary Lewis', u'Jamie Sives', u'Ewan Stewart', u'Alexander Morton', u'Callum Mitchell', u'Andrew Flanagan', u'Douglas Russell', u'Maarten Stevenson', u'Gordon Brown', u'Gary McCormack', u'Robert Harrison', u'Mathew Zajac', u'Stewart Porter', u'James Ramsey', u'Rony Bridges', u'P.B. McBeath']
# CHAR [u'One-Eye', u'Kare', u'Gorm', u'Eirik', u'Barde', u'Pagan Viking Guard', u'Duggal', u'Olaf', u'Are / The Boy', u'Hagen', u'Hauk', u'Roger', u'Malkolm', u'Kenneth', u'Gudmund', u'Magnus', u'Man with pike']
# 4.881914, max of:
#   4.881914, sum of:
#     4.881914, weight(cast.name:stewart in 965) [PerFieldSimilarity], result of:
#       4.881914, score(freq=2.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.64064634, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           2.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           34.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 46	4.8770733		The Collector
# The Collector
# He always takes one
# Desperate to repay his debt to his ex-wife, an ex-con plots a heist at his new employer's country home, unaware that a second criminal has also targeted the property, and rigged it with a series of deadly traps.
# 21407
# DIRS [u'Marcus Dunstan']
# CAST [u'Josh Stewart', u'Michael Reilly Burke', u'Andrea Roth', u'Juan Fern\xe1ndez', u'Madeline Zima', u'Karley Scott Collins', u'Robert Wisdom', u'Daniella Alonso', u'Haley Pullos', u'Diane Ayala Goldner', u'Alex Feldman', u'Krystal Mayo', u'Gregory Alan Williams', u'Michael Showers', u'Bill Stinchcomb', u'Brett Forbes', u'Eric Kelly McFarland', u'Jabari Thomas', u'Hiro Koda', u'Colvin Roberson', u'John Snell', u'Jon Dainty', u'William Morse', u'David Pitt', u'Philip Poth', u'Patrick Rizzotti', u'Tom Gulager']
# CHAR [u'Arkin', u'Michael Chase', u'Victoria Chase', u'The Collector', u'Jill Chase', u'Hannah Chase', u'Roy', u'Lisa', u'Cindy (as Haley Alexis Pullos)', u'Gena Wharton', u'Chad', u'Bar Dancer', u'Sheriff', u'Deputy sheriff', u'Bar Patron', u'Office Hoss Wiggins', u'Firefighter', u'Medic', u'Medic #2', u"Roy's Driver / Bodyguard", u'Yard Worker', u'Strip Club Patron (uncredited)', u'Stabbed Man (uncredited)', u'Barman (uncredited)', u'Foreman (uncredited)', u'Bowling Ball Cleaner (uncredited)', u'Officer Gulager']
# 4.8770733, max of:
#   4.8770733, sum of:
#     2.0054247, weight(cast.name:patrick in 234) [PerFieldSimilarity], result of:
#       2.0054247, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         2.4189348, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           271, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.37684214, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           56.0, dl, length of field (approximate)
#           37.233192, avgdl, average length of field
#     2.8716488, weight(cast.name:stewart in 234) [PerFieldSimilarity], result of:
#       2.8716488, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.37684214, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           56.0, dl, length of field (approximate)
#           37.233192, avgdl, average length of field
#
# *************************************
# 47	4.7924466		Guess Who
# Guess Who
# His house. His rules. Some in-laws were made to be broken.
# The fiancé of an African-American woman who's met with skepticism and suspicion from her father. Tension flares -- along with comedy -- when she takes him home for the all-important introduction, and as the wedding approaches, Dad must come to terms with his future son-in-law.
# 11638
# DIRS [u'Kevin Rodney Sullivan']
# CAST [u'Bernie Mac', u'Ashton Kutcher', u'Zoe Saldana', u'Judith Scott', u'Hal Williams', u'Kellee Stewart']
# CHAR [u'Percy Jones', u'Simon Green', u'Theresa Jones', u'Marilyn Jones', u'Howard Jones', u'Keisha Jones']
# 4.7924466, max of:
#   4.7924466, sum of:
#     4.7924466, weight(cast.name:stewart in 188) [PerFieldSimilarity], result of:
#       4.7924466, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.6289056, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           12.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 48	4.7710886		The Inbetweeners Movie
# The Inbetweeners Movie
# This year four boys become men.
# High school graduation just wouldn’t be complete without an un-chaperoned, uninhibited and unforgettable final holiday. At least that’s what Will, Jay, Simon and Neil think when they book a two-week stay on an exotic Greek island. As their dreams of sun-drenched days and booze-filled nights are left hopelessly unfulfilled, the lads fight their way into the party scene with hilariously humiliating results in this smash hit UK raunchy comedy.
# 69798
# DIRS [u'Ben Palmer']
# CAST [u'Simon Bird', u'James Buckley', u'Blake Harrison', u'Joe Thomas', u'Lydia Rose Bewley', u'Laura Haddock', u'Emily Head', u'Tamla Kari', u'Jessica Knappett', u'Theo Barklem-Biggs', u'Theo James', u'Anthony Stewart Head', u'Victoria Willing', u'Greg Davies', u'Henry Lloyd-Hughes', u'Belinda Stewart-Wilson']
# CHAR [u'Will McKenzie', u'Jay Cartwright', u'Neil Sutherland', u'Simon Cooper', u'Jane', u'Alison', u"Carli D'Amato", u'Lucy', u'Lisa', u'Richard', u'James', u"Will's Dad", u'Mrs. Cartwright', u'Mr. Gilbert', u'Mark Donovan', u'Polly MacKenzie']
# 4.7710886, max of:
#   4.7710886, sum of:
#     4.7710886, weight(cast.name:stewart in 812) [PerFieldSimilarity], result of:
#       4.7710886, score(freq=2.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.62610286, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           2.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           37.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 49	4.720683		The Last Starfighter
# The Last Starfighter
# He didn't find his dreams... his dreams found him.
# A video-gaming boy, seemingly doomed to stay at his trailer park home all his life, finds himself recruited as a gunner for an alien defense force.
# 11884
# DIRS [u'Nick Castle']
# CAST [u'Lance Guest', u"Dan O'Herlihy", u'Catherine Mary Stewart', u'Barbara Bosson', u'Norman Snow', u'Robert Preston']
# CHAR [u'Alex Rogan', u'Grig', u'Maggie Gordon', u'Jane Rogan', u'Xur', u'Centauri']
# 4.720683, max of:
#   4.720683, sum of:
#     4.720683, weight(cast.name:stewart in 2016) [PerFieldSimilarity], result of:
#       4.720683, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.61948824, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           13.0, dl, length of field
#           37.233192, avgdl, average length of field
#
# *************************************
# 50	4.6651835		The Twilight Saga: Breaking Dawn - Part 1
# The Twilight Saga: Breaking Dawn - Part 1
# Forever is just the beginning
# The new found married bliss of Bella Swan and vampire Edward Cullen is cut short when a series of betrayals and misfortunes threatens to destroy their world. Bella soon discovers she is pregnant, and during a nearly fatal childbirth, Edward finally fulfills her wish to become immortal. But the arrival of their remarkable daughter, Renesmee, sets in motion a perilous chain of events that pits the Cullens and their allies against the Volturi, the fearsome council of vampire leaders, setting the stage for an all-out battle.
# 50619
# DIRS [u'Bill Condon']
# CAST [u'Kristen Stewart', u'Robert Pattinson', u'Taylor Lautner', u'Ashley Greene', u'Peter Facinelli', u'Elizabeth Reaser', u'Kellan Lutz', u'Anna Kendrick', u'Booboo Stewart', u'Julia Jones', u'Nikki Reed', u'Jackson Rathbone', u'Chaske Spencer', u'Maggie Grace', u'Billy Burke', u'Dakota Fanning', u'Sarah Clarke', u'MyAnna Buring', u'Tanaya Beatty', u'Christian Camargo']
# CHAR [u'Bella Swan', u'Edward Cullen', u'Jacob Black', u'Alice Cullen', u'Carlisle Cullen', u'Esme Cullen', u'Emmett Cullen', u'Jessica', u'Seth', u'Leah', u'Rosalie Hale', u'Jasper Hale', u'Sam Uley', u'Irina Denali', u'Charlie Swan', u'Jane', u'Ren\xe9e', u'Tanya Denali', u'Rachel', u'Eleazar']
# 4.6651835, max of:
#   4.6651835, sum of:
#     4.6651835, weight(cast.name:stewart in 2320) [PerFieldSimilarity], result of:
#       4.6651835, score(freq=2.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.4637706, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           95, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.612205, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           2.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           40.0, dl, length of field (approximate)
#           37.233192, avgdl, average length of field
#
# *************************************
# *************************************
# {
#   "valid": false
# }

# %% [markdown]
# # 5.3.2 -- Listing 7 -- Reducing the Impact of directors.name

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview',
                       'cast.name', 'directors.name^0.1'],  #A    
         }
    },
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	7.1845765		Hannah Montana: The Movie
# 2	7.1596975		Vertigo
# 3	6.9732013		Star Trek: Insurrection
# 4	6.9093037		One Flew Over the Cuckoo's Nest
# 5	6.71099		Star Trek: First Contact
# 6	6.5468693		Gnomeo & Juliet
# 7	6.5468693		Excalibur
# 8	6.465148		X-Men: Days of Future Past
# 9	6.3152065		Panic Room
# 10	6.2415876		Conspiracy Theory

# %% [markdown]
# # 5.3.3 -- Listings 8&9  – Analysis Extracting English Bigrams

# %%
analysisSettings = {
   "analyzer" : {
      "default" : {
        "type" : "english"
      },
      "english_bigrams": {
          "type": "custom",
          "tokenizer": "standard",
          "filter": [
            "lowercase",
            "porter_stem",
            "bigram_filter"
          ]
      }
    },
  "filter": {
    "bigram_filter": {
        "type": "shingle",
        "max_shingle_size":2,
        "min_shingle_size":2,
        "output_unigrams":"false"
    }
  }
}


# From listing 9
mappingSettings = {
        'properties': {
             'title': { #A
                   'type': 'text',
                   'analyzer': 'english'
               },
            'overview': {
                   'type': 'text',
                   'analyzer': 'english'
               },
            "cast": {
                'properties': {
                  "name":{
                      'type': 'text',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "text",
                            "analyzer": "english_bigrams"
                        }     
                      }
                   
                  }
                }
            },
            "directors": {
                'properties': {
                "name":{
                      'type': 'text',
                      'analyzer': 'english',
                      'fields': {
                         "bigramed": {
                            "type": "text",
                            "analyzer": "english_bigrams"
                        }     
                      }
                }
                }
               }
                    
        }
}

reindex(analysisSettings, mappingSettings, movieDict)
# Out:
# Delete TMDB Index <{u'acknowledged': True}>
# Create TMDB Index <{u'index': u'tmdb', u'acknowledged': True, u'shards_acknowledged': True}>
# Indexing 3051 movies
# creating...
# indexing...

# %% [markdown]
# # 5.3.3 -- Listing 10 -- Searching *.bigramed fields, reindexing

# %%
usersSearch = 'patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview',
'cast.name.bigramed', 'directors.name.bigramed'],      
         }
    },
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	7.1845765		Hannah Montana: The Movie
# 2	6.9093037		One Flew Over the Cuckoo's Nest
# 3	6.228061		The Bounty Hunter
# 4	6.058046		Star Trek: Insurrection
# 5	5.910869		Star Trek: First Contact
# 6	5.7706733		Gnomeo & Juliet
# 7	5.7706733		Excalibur
# 8	5.443809		The SpongeBob SquarePants Movie
# 9	5.443809		10 Things I Hate About You
# 10	5.3873396		Conspiracy Theory

# %% [markdown]
# # 5.3.4	Letting Losers Share The Glory (no listing number)

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed^5', 'directors.name.bigramed'],      
            'type': 'best_fields',
            'tie_breaker': 0.4
         }
    },
    'size': 5,
    'explain': True
}
search(query)
print "==============="
search(query, verbose=True)
# Out:
# Num	Relevance Score		Movie Title
# 1	33.893368		Star Trek: Insurrection
# 2	32.65286		Star Trek: First Contact
# 3	31.895023		Star Trek: Generations
# 4	30.539837		Star Trek: Nemesis
# 5	28.853365		Gnomeo & Juliet
# ===============
# Num	Relevance Score		Movie Title
# 1	33.893368		Star Trek: Insurrection
# Star Trek: Insurrection
# The battle for paradise has begun.
# When an alien race and factions within Starfleet attempt to take over a planet that has "regenerative" properties, it falls upon Captain Picard and the crew of the Enterprise to defend the planet's people as well as the very ideals upon which the Federation itself was founded.
# 200
# DIRS [u'Jonathan Frakes']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Gates McFadden', u'Marina Sirtis', u'F. Murray Abraham', u'Anthony Zerbe', u'Donna Murphy', u'Gregg Henry', u'Michael Dorn']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Doctor Beverly Crusher', u'Counselor Deanna Troi', u"Ad'har Ru'afo", u'Vice-Adm. Dougherty', u'Anij', u'Gallatin', u'Lt. Commander Worf']
# 33.893368, max plus 0.4 times others of:
#   9.007851, sum of:
#     4.249565, weight(title:star in 578) [PerFieldSimilarity], result of:
#       4.249565, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         4.910037, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           22, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.3934024, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           3.0, dl, length of field
#           2.1740413, avgdl, average length of field
#     4.7582855, weight(title:trek in 578) [PerFieldSimilarity], result of:
#       4.7582855, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         5.4978237, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           12, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.3934024, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           3.0, dl, length of field
#           2.1740413, avgdl, average length of field
#   30.290226, sum of:
#     30.290226, weight(cast.name.bigramed:patrick stewart in 578) [PerFieldSimilarity], result of:
#       30.290226, score(freq=1.0), computed as boost * idf * tf from:
#         11.0, boost
#         5.105126, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           18, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.5393906, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           12.0, dl, length of field
#           19.496555, avgdl, average length of field
#
# *************************************
# 2	32.65286		Star Trek: First Contact
# Star Trek: First Contact
# Resistance is futile.
# The Borg, a relentless race of cyborgs, are on a direct course for Earth. Violating orders to stay away from the battle, Captain Picard and the crew of the newly-commissioned USS Enterprise E pursue the Borg back in time to prevent the invaders from changing Federation history and assimilating the galaxy.
# 199
# DIRS [u'Jonathan Frakes']
# CAST [u'James Cromwell', u'Alfre Woodard', u'Alice Krige', u'Neal McDonough', u'Patrick Stewart', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'Jonathan Frakes', u'Dwight Schultz', u'Cameron Oppenheimer']
# CHAR [u'Dr. Zefram Cochrane', u'Lily Sloane', u'Borg Queen', u'Lieutenant Hawk', u'Captain Jean-Luc Picard', u'Lt. Commander Data', u'Commander Geordi La Forge', u'Lieutenant Commander Worf', u'Commander Beverly Crusher', u'Ships Counselor Commander Deanna Troi', u'Commander William Riker', u'Lt. Barclay', u'Ensign Kellogg']
# 32.65286, max plus 0.4 times others of:
#   7.7462955, sum of:
#     3.6544108, weight(title:star in 1034) [PerFieldSimilarity], result of:
#       3.6544108, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         4.910037, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           22, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.33830613, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           4.0, dl, length of field
#           2.1740413, avgdl, average length of field
#     4.0918846, weight(title:trek in 1034) [PerFieldSimilarity], result of:
#       4.0918846, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         5.4978237, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           12, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.33830613, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           4.0, dl, length of field
#           2.1740413, avgdl, average length of field
#   29.554342, sum of:
#     29.554342, weight(cast.name.bigramed:patrick stewart in 1034) [PerFieldSimilarity], result of:
#       29.554342, score(freq=1.0), computed as boost * idf * tf from:
#         11.0, boost
#         5.105126, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           18, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.5262864, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           13.0, dl, length of field
#           19.496555, avgdl, average length of field
#
# *************************************
# 3	31.895023		Star Trek: Generations
# Star Trek: Generations
# Boldly go.
# Captain Jean-Luc Picard and the crew of the Enterprise-D find themselves at odds with the renegade scientist Soran who is destroying entire star systems. Only one man can help Picard stop Soran's scheme...and he's been dead for seventy-eight years.
# 193
# DIRS [u'David Carson']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'Brent Spiner', u'LeVar Burton', u'Michael Dorn', u'Gates McFadden', u'Marina Sirtis', u'William Shatner', u'James Doohan', u'Walter Koenig', u'Malcolm McDowell', u'Alan Ruck', u'Whoopi Goldberg', u'Thomas Dekker', u'Cameron Oppenheimer', u'Jenette Goldstein', u'Tim Russ']
# CHAR [u'Captain Jean-Luc Picard', u'Commander William T. Riker', u'Lt. Commander Data', u'Lt. Commander Geordi La Forge', u'Lt. Commander Worf', u'Dr. Beverly Crusher', u'Commander Deanna Troi', u'James T. Kirk', u'Montgomery Scott', u'Pavel Chekov', u'Dr. Tolian Soran', u'Capt. John Harriman', u'Guinan', u"Picard's Kid", u'Ensign Kellogg', u'Science Officer', u'Lieutenant']
# 31.895023, max plus 0.4 times others of:
#   3.3879652, sum of:
#     3.3879652, weight(overview:star in 1042) [PerFieldSimilarity], result of:
#       3.3879652, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         3.2483118, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           118, n, number of documents containing term
#           3050, N, total number of documents with field
#         0.47408754, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           33.0, dl, length of field
#           36.697704, avgdl, average length of field
#   9.007851, sum of:
#     4.249565, weight(title:star in 1042) [PerFieldSimilarity], result of:
#       4.249565, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         4.910037, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           22, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.3934024, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           3.0, dl, length of field
#           2.1740413, avgdl, average length of field
#     4.7582855, weight(title:trek in 1042) [PerFieldSimilarity], result of:
#       4.7582855, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         5.4978237, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           12, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.3934024, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           3.0, dl, length of field
#           2.1740413, avgdl, average length of field
#   26.936697, sum of:
#     26.936697, weight(cast.name.bigramed:patrick stewart in 1042) [PerFieldSimilarity], result of:
#       26.936697, score(freq=1.0), computed as boost * idf * tf from:
#         11.0, boost
#         5.105126, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           18, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.4796729, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           17.0, dl, length of field
#           19.496555, avgdl, average length of field
#
# *************************************
# 4	30.539837		Star Trek: Nemesis
# Star Trek: Nemesis
# A generation's final journey... begins.
# En route to the honeymoon of William Riker to Deanna Troi on her home planet of Betazed, Captain Jean-Luc Picard and the crew of the U.S.S. Enterprise receives word from Starfleet that a coup has resulted in the installation of a new Romulan political leader, Shinzon, who claims to seek peace with the human-backed United Federation of Planets. Once in enemy territory, the captain and his crew make a startling discovery: Shinzon is human, a slave from the Romulan sister planet of Remus, and has a secret, shocking relationship to Picard himself.
# 201
# DIRS [u'Stuart Baird']
# CAST [u'Patrick Stewart', u'Jonathan Frakes', u'LeVar Burton', u'Brent Spiner', u'Gates McFadden', u'Marina Sirtis', u'Tom Hardy', u'Ron Perlman', u'Shannon Cochran', u'Dina Meyer', u'Michael Dorn', u'Kate Mulgrew', u'Wil Wheaton', u'Whoopi Goldberg', u'Stuart Baird', u'Alan Dale', u'Bryan Singer']
# CHAR [u'Captain Jean-Luc Picard', u'Captain William T. Riker', u'Lt. Commander Geordi La Forge', u'Lt. Commander Data', u'Dr. Beverly Crusher', u'Counselor Deanna Troi-Riker', u'Praetor Shinzon', u'The Reman Viceroy', u"Senator Tal'aura", u'Commander Donatra', u'Lt. Commander Worf', u'Admiral Janeway', u'Wesley Crusher', u'Guinan', u'Scimitar Computer (voice)', u'Praetor Hiren', u'Kelly (uncredited)']
# 30.539837, max plus 0.4 times others of:
#   9.007851, sum of:
#     4.249565, weight(title:star in 577) [PerFieldSimilarity], result of:
#       4.249565, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         4.910037, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           22, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.3934024, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           3.0, dl, length of field
#           2.1740413, avgdl, average length of field
#     4.7582855, weight(title:trek in 577) [PerFieldSimilarity], result of:
#       4.7582855, score(freq=1.0), computed as boost * idf * tf from:
#         2.2, boost
#         5.4978237, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           12, n, number of documents containing term
#           3051, N, total number of documents with field
#         0.3934024, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           3.0, dl, length of field
#           2.1740413, avgdl, average length of field
#   26.936697, sum of:
#     26.936697, weight(cast.name.bigramed:patrick stewart in 577) [PerFieldSimilarity], result of:
#       26.936697, score(freq=1.0), computed as boost * idf * tf from:
#         11.0, boost
#         5.105126, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           18, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.4796729, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           17.0, dl, length of field
#           19.496555, avgdl, average length of field
#
# *************************************
# 5	28.853365		Gnomeo & Juliet
# Gnomeo & Juliet
# A little adventure goes a lawn way.
# A version of Shakespeare's play, set in the world of warring indoor and outdoor gnomes. Garden gnomes Gnomeo and Juliet have as many obstacles to overcome as their quasi namesakes when they are caught up in a feud between neighbors. But with plastic pink flamingos and lawnmower races in the mix, can this young couple find lasting happiness?
# 45772
# DIRS [u'Kelly Asbury']
# CAST [u'Jason Statham', u'James McAvoy', u'Michael Caine', u'Maggie Smith', u'Julie Walters', u'Patrick Stewart', u'Jim Cummings', u'Ashley Jensen', u'Dolly Parton', u'Matt Lucas', u'Hulk Hogan', u'Stephen Merchant', u'Ozzy Osbourne', u'Emily Blunt']
# CHAR [u'Tybalt (voice)', u'Gnomeo (voice)', u'Lord Redbrick (voice)', u'Lady Bluebury (voice)', u'Lady Montague (voice)', u'William Shakespeare (voice)', u'Featherstone (voice)', u'Nanette (voice)', u'Dolly Gnome (voice)', u'Benny (voice)', u'Terrafirminator V.O. (voice)', u'Paris (voice)', u'Fawn (voice)', u'Juliet (voice)']
# 28.853365, max plus 0.4 times others of:
#   28.853365, sum of:
#     28.853365, weight(cast.name.bigramed:patrick stewart in 886) [PerFieldSimilarity], result of:
#       28.853365, score(freq=1.0), computed as boost * idf * tf from:
#         11.0, boost
#         5.105126, idf, computed as log(1 + (N - n + 0.5) / (n + 0.5)) from:
#           18, n, number of documents containing term
#           3049, N, total number of documents with field
#         0.51380384, tf, computed as freq / (freq + k1 * (1 - b + b * dl / avgdl)) from:
#           1.0, freq, occurrences of term within document
#           1.2, k1, term saturation parameter
#           0.75, b, length normalization parameter
#           14.0, dl, length of field
#           19.496555, avgdl, average length of field
#
# *************************************
# *************************************
# {
#   "valid": false
# }

# %% [markdown]
# # 5.3.5, Listing 11 Counting Multiple Signals using Most Fields

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview',
'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    }
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	17.783155		Star Trek: Generations
# 2	15.065897		Star Trek: Insurrection
# 3	14.39519		Star Trek: Nemesis
# 4	13.657165		Star Trek: First Contact
# 5	10.878148		Hannah Montana: The Movie
# 6	10.760254		Star Trek
# 7	9.007851		Star Trek Into Darkness
# 8	8.387256		Maps to the Stars
# 9	8.1140175		Dinosaur
# 10	8.019917		The Beaver

# %% [markdown]
# # 5.3.6, Listing 12	Boosting in Most-Fields

# %%
usersSearch = 'star trek patrick stewart'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.2', 'overview',
 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    },
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	10.878148		Hannah Montana: The Movie
# 2	10.576875		Star Trek: Generations
# 3	8.1140175		Dinosaur
# 4	8.019917		The Beaver
# 5	7.8596163		Star Trek: Insurrection
# 6	7.4601283		Star Trek: First Contact
# 7	7.1889095		Star Trek: Nemesis
# 8	6.94131		Ted
# 9	6.9093037		One Flew Over the Cuckoo's Nest
# 10	6.811893		The Lord of the Rings: The Two Towers

# %% [markdown]
# # 5.3.7	When Additional Matches Don’t Matter (no listing number)

# %%
usersSearch = 'star trek patrick stewart william shatner'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title', 'overview', 'cast.name.bigramed', 'directors.name.bigramed'],      
            'type': 'most_fields'
         }
    },
    'size': 5,
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title
# 1	23.29123		Star Trek: Generations
# 2	22.615887		Star Trek IV: The Voyage Home
# 3	20.892147		Star Trek V: The Final Frontier
# 4	18.406107		Star Trek: Nemesis
# 5	15.065897		Star Trek: Insurrection
